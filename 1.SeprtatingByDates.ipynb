# %%
import os
import json
import gzip
import io
import glob
import pickle

# %%
#Saving all the dates in date_dict

if(os.path.exists('/dates_dict.pkl')):
    pkl_file = open('/dates_dict.pkl', 'rb')
    date_dict = pickle.load(pkl_file)
    pkl_file.close()

else: date_dict = {}
    
all_gz_files = glob.glob("/dnc2020/**/*.gz")

for file_path in all_gz_files:
    path_arr = file_path.split("/")
    date = path_arr[4].split()
    if date[0] not in date_dict:
        date_dict[date[0]] = "not_processed"

output = open('/dates_dict.pkl', 'wb')
pickle.dump(date_dict, output)
output.close()


if(os.path.exists('/tweets_count.pkl')):
    pkl_file = open('/tweets_count.pkl', 'rb')
    tweets_count = pickle.load(pkl_file)
    pkl_file.close()

else: tweets_count = {}

# date_dict

# %%
#function to extract the tweet text form the raw json of a tweet

def getTweetText(tweet):
    temp_text = ""
    if "extended_tweet" in tweet:
        tweet_details = tweet["extended_tweet"]
        temp_text += "" +tweet_details["full_text"]
    
    #if any tweet was retweeted
    elif "retweeted_status" in tweet:
        #if extended text available in the original tweet
        if("extended_tweet" in tweet["retweeted_status"]):
            tweet_details = tweet["retweeted_status"]["extended_tweet"]
            temp_text += "" +tweet_details["full_text"]
                    
        #getting the text of the original
        elif "text" in tweet["retweeted_status"]:
            tweet_details = tweet["retweeted_status"]["text"]
            temp_text += "" +tweet_details
    else:
        temp_text += "" +tweet["text"]
            
    return temp_text

# %%
for date in date_dict:
    if date_dict[date] == "not_processed":
        all_gz_files = glob.glob("/dnc2020/" +date+"*/*.gz")    
        tweets = {}  #dict
        
        i=0 #keeps the track of # of files for a date
        j=0 #keeps a track of the # of tweets in a file
        total_tweets = 0 #keeps a track of the total tweets on a date
        for file_path in all_gz_files:
            i +=1; 
            j = 0 
            print(str(i)+"/"+str(len(all_gz_files))+"...reading file "+file_path.rstrip())
            try:
                gz = gzip.open(file_path, 'r')
                f = io.BufferedReader(gz)

                #creating a dictionary of the tweets [(tweet_id)key : (tweet)value]
                for line in f:
                    j +=1
                    if(j%100==0):
                        print("..........processed " +str(j) +" tweets", end="\r" )
                    total_tweets +=1
#                     if(j%1000000==0): break   #limiting to reading 1M tweets per file
                    temp_tweet_json = json.loads(line)
                    key = temp_tweet_json["id"]
                    
                    #creating a dict of only the essential fields from the tweet to save in the 'tweets' dict
                    value = {}
                    value['created_at'] = temp_tweet_json['created_at']
                    value['tweet_text'] = getTweetText(temp_tweet_json)
                    value['id'] = temp_tweet_json["id"]
                    value['user_id'] = temp_tweet_json['user']['id']
                    if "retweeted_status" in temp_tweet_json:
                        value['hashtags'] = temp_tweet_json['retweeted_status']['entities']['hashtags']
                        value['user_mentions'] = temp_tweet_json['retweeted_status']['entities']['user_mentions']
                    else: 
                        value['hashtags'] = temp_tweet_json['entities']['hashtags']
                        value['user_mentions'] = temp_tweet_json['entities']['user_mentions']
                        
                    tweets.update( {key : value} )
                print("..........processed " +str(j) +" tweets")
             
            except EOFError as error:
                error_log_file = open("EOFError_files.txt","a+") 
                error_log_file.write(file_path + "|" + str(total_tweets) + "\n");                  
                error_log_file.close()
                print("EOFError")

        print()
        print("Number of tweets on " + date +": " +str(total_tweets))
        print()
        
        output = open('/Processed Tweets/tweets_' +date+'.pkl', 'wb')
        pickle.dump(tweets, output)
        output.close()
              
        date_dict[date] = 'processed'
        tweets_count[date] = total_tweets
             
        output = open('/dates_dict.pkl', 'wb')
        pickle.dump(date_dict, output)
        output.close()
        
        output = open('/tweets_count.pkl', 'wb')
        pickle.dump(tweets_count, output)
        output.close()
# Out:
# 1/17...reading file /dnc2020/2020-03-26 13:50:34.030000--4/output_4.txt.gz
# ..........processed 29766 tweets
# 2/17...reading file /dnc2020/2020-03-26 15:26:10.532562--1/output_1.txt.gz
# EOFError..processed 7800 tweets
# 3/17...reading file /dnc2020/2020-03-26 13:11:57.916117--2/output_2.txt.gz
# ..........processed 1113 tweets
# 4/17...reading file /dnc2020/2020-03-26 16:56:59.179055--4/output_4.txt.gz
# EOFError..processed 563900 tweets
# 5/17...reading file /dnc2020/2020-03-26 16:56:59.180648--5/output_5.txt.gz
# ..........processed 89364 tweets
# 6/17...reading file /dnc2020/2020-03-26 13:28:30.686000--1/output_1.txt.gz
# EOFError..processed 8400 tweets
# 7/17...reading file /dnc2020/2020-03-26 14:50:52.541987--4/output_4.txt.gz
# EOFError..processed 18300 tweets
# 8/17...reading file /dnc2020/2020-03-26 15:26:10.532920--2/output_2.txt.gz
# EOFError..processed 19700 tweets
# 9/17...reading file /dnc2020/2020-03-26 13:23:00.597409--5/output_5.txt.gz
# EOFError..processed 21900 tweets
# 10/17...reading file /dnc2020/2020-03-26 13:39:33.102000--2/output_2.txt.gz
# EOFError..processed 19900 tweets
# 11/17...reading file /dnc2020/2020-03-26 16:56:59.178068--2/output_2.txt.gz
# ..........processed 129398 tweets
# 12/17...reading file /dnc2020/2020-03-26 15:26:10.534226--5/output_5.txt.gz
# EOFError..processed 17100 tweets
# 13/17...reading file /dnc2020/2020-03-26 16:56:59.177555--1/output_1.txt.gz
# ..........processed 127180 tweets
# 14/17...reading file /dnc2020/2020-03-26 16:56:59.178492--3/output_3.txt.gz
# EOFError..processed 1344300 tweets
# 15/17...reading file /dnc2020/2020-03-26 13:50:35.421996--3/output_3.txt.gz
# EOFError..processed 64700 tweets
# 16/17...reading file /dnc2020/2020-03-26 15:26:10.533892--4/output_4.txt.gz
# EOFError..processed 52000 tweets
# 17/17...reading file /dnc2020/2020-03-26 15:26:10.533597--3/output_3.txt.gz
# EOFError..processed 75400 tweets
#
# Number of tweets on 2020-03-26: 2590918
#
# 1/68...reading file /dnc2020/2020-01-31 07:06:24.931962--4/output_4.txt.gz
# ..........processed 248512 tweets
# 2/68...reading file /dnc2020/2020-01-31 19:43:37.756478--5/output_5.txt.gz
# ..........processed 0 tweets
# 3/68...reading file /dnc2020/2020-01-31 19:45:10.073873--3/output_3.txt.gz
# ..........processed 0 tweets
# 4/68...reading file /dnc2020/2020-01-31 19:45:40.136394--4/output_4.txt.gz
# ..........processed 184167 tweets
# 5/68...reading file /dnc2020/2020-01-31 19:45:10.075223--5/output_5.txt.gz
# ..........processed 0 tweets
# 6/68...reading file /dnc2020/2020-01-31 19:42:37.660303--2/output_2.txt.gz
# ..........processed 0 tweets
# 7/68...reading file /dnc2020/2020-01-31 19:44:07.780604--5/output_5.txt.gz
# ..........processed 0 tweets
# 8/68...reading file /dnc2020/2020-01-31 19:42:57.685070--2/output_2.txt.gz
# ..........processed 0 tweets
# 9/68...reading file /dnc2020/2020-01-31 19:42:41.514496--1/output_1.txt.gz
# ..........processed 0 tweets
# 10/68...reading file /dnc2020/2020-01-31 19:45:20.107514--5/output_5.txt.gz
# ..........processed 0 tweets
# 11/68...reading file /dnc2020/2020-01-31 19:44:56.497774--4/output_4.txt.gz
# ..........processed 0 tweets
# 12/68...reading file /dnc2020/2020-01-31 19:43:17.769610--3/output_3.txt.gz
# ..........processed 0 tweets
# 13/68...reading file /dnc2020/2020-01-31 19:44:45.069199--1/output_1.txt.gz
# ..........processed 0 tweets
# 14/68...reading file /dnc2020/2020-01-31 07:06:17.160547--1/output_1.txt.gz
# ..........processed 19000 tweets
# 15/68...reading file /dnc2020/2020-01-31 19:45:20.093268--3/output_3.txt.gz
# ..........processed 0 tweets
# 16/68...reading file /dnc2020/2020-01-31 19:44:31.640433--1/output_1.txt.gz
# ..........processed 0 tweets
# 17/68...reading file /dnc2020/2020-01-31 19:42:57.744574--3/output_3.txt.gz
# ..........processed 0 tweets
# 18/68...reading file /dnc2020/2020-01-31 19:44:07.780524--2/output_2.txt.gz
# ..........processed 0 tweets
# 19/68...reading file /dnc2020/2020-01-31 19:45:10.075175--1/output_1.txt.gz
# ..........processed 0 tweets
# 20/68...reading file /dnc2020/2020-01-31 19:45:30.126266--5/output_5.txt.gz
# ..........processed 0 tweets
# 21/68...reading file /dnc2020/2020-01-31 19:43:37.792463--3/output_3.txt.gz
# ..........processed 0 tweets
# 22/68...reading file /dnc2020/2020-01-31 19:45:10.073937--2/output_2.txt.gz
# ..........processed 0 tweets
# 23/68...reading file /dnc2020/2020-01-31 19:42:37.724024--3/output_3.txt.gz
# ..........processed 0 tweets
# 24/68...reading file /dnc2020/2020-01-31 19:45:40.118271--3/output_3.txt.gz
# ..........processed 96017 tweets
# 25/68...reading file /dnc2020/2020-01-31 19:44:56.498346--1/output_1.txt.gz
# ..........processed 0 tweets
# 26/68...reading file /dnc2020/2020-01-31 19:44:02.813774--3/output_3.txt.gz
# ..........processed 0 tweets
# 27/68...reading file /dnc2020/2020-01-31 19:43:41.766665--4/output_4.txt.gz
# ..........processed 0 tweets
# 28/68...reading file /dnc2020/2020-01-31 19:44:11.796820--4/output_4.txt.gz
# ..........processed 0 tweets
# 29/68...reading file /dnc2020/2020-01-31 07:00:56.864450--2/output_2.txt.gz
# ..........processed 31030 tweets
# 30/68...reading file /dnc2020/2020-01-31 19:44:45.069766--2/output_2.txt.gz
# ..........processed 0 tweets
# 31/68...reading file /dnc2020/2020-01-31 06:50:00.776687--5/output_5.txt.gz
# ..........processed 81505 tweets
# 32/68...reading file /dnc2020/2020-01-31 19:43:21.562790--1/output_1.txt.gz
# ..........processed 0 tweets
# 33/68...reading file /dnc2020/2020-01-31 19:43:41.588901--1/output_1.txt.gz
# ..........processed 0 tweets
# 34/68...reading file /dnc2020/2020-01-31 19:44:45.069337--4/output_4.txt.gz
# ..........processed 0 tweets
# 35/68...reading file /dnc2020/2020-01-31 19:44:45.070782--5/output_5.txt.gz
# ..........processed 0 tweets
# 36/68...reading file /dnc2020/2020-01-31 06:44:32.597924--5/output_5.txt.gz
# ..........processed 416 tweets
# 37/68...reading file /dnc2020/2020-01-31 19:44:56.498648--3/output_3.txt.gz
# ..........processed 0 tweets
# 38/68...reading file /dnc2020/2020-01-31 19:43:37.733811--2/output_2.txt.gz
# ..........processed 0 tweets
# 39/68...reading file /dnc2020/2020-01-31 06:50:02.033091--4/output_4.txt.gz
# ..........processed 3247 tweets
# 40/68...reading file /dnc2020/2020-01-31 07:11:51.609860--3/output_3.txt.gz
# ..........processed 184640 tweets
# 41/68...reading file /dnc2020/2020-01-31 19:44:56.498407--5/output_5.txt.gz
# ..........processed 0 tweets
# 42/68...reading file /dnc2020/2020-01-31 19:45:20.102969--4/output_4.txt.gz
# ..........processed 0 tweets
# 43/68...reading file /dnc2020/2020-01-31 19:42:57.690589--5/output_5.txt.gz
# ..........processed 0 tweets
# 44/68...reading file /dnc2020/2020-01-31 19:44:31.821510--4/output_4.txt.gz
# ..........processed 0 tweets
# 45/68...reading file /dnc2020/2020-01-31 19:45:10.075570--4/output_4.txt.gz
# ..........processed 0 tweets
# 46/68...reading file /dnc2020/2020-01-31 19:43:21.741560--4/output_4.txt.gz
# ..........processed 0 tweets
# 47/68...reading file /dnc2020/2020-01-31 19:45:30.112872--1/output_1.txt.gz
# ..........processed 0 tweets
# 48/68...reading file /dnc2020/2020-01-31 19:44:11.616618--1/output_1.txt.gz
# ..........processed 0 tweets
# 49/68...reading file /dnc2020/2020-01-31 19:45:30.112948--2/output_2.txt.gz
# ..........processed 0 tweets
# 50/68...reading file /dnc2020/2020-01-31 19:44:27.798158--5/output_5.txt.gz
# ..........processed 0 tweets
# 51/68...reading file /dnc2020/2020-01-31 19:42:41.684522--4/output_4.txt.gz
# ..........processed 0 tweets
# 52/68...reading file /dnc2020/2020-01-31 06:44:32.305070--4/output_4.txt.gz
# ..........processed 1106 tweets
# 53/68...reading file /dnc2020/2020-01-31 19:44:56.498468--2/output_2.txt.gz
# ..........processed 0 tweets
# 54/68...reading file /dnc2020/2020-01-31 19:44:22.838682--3/output_3.txt.gz
# ..........processed 0 tweets
# 55/68...reading file /dnc2020/2020-01-31 19:43:01.536563--1/output_1.txt.gz
# ..........processed 0 tweets
# 56/68...reading file /dnc2020/2020-01-31 19:45:40.126977--1/output_1.txt.gz
# ..........processed 21139 tweets
# 57/68...reading file /dnc2020/2020-01-31 19:45:20.103193--1/output_1.txt.gz
# ..........processed 0 tweets
# 58/68...reading file /dnc2020/2020-01-31 19:43:01.720138--4/output_4.txt.gz
# ..........processed 0 tweets
# 59/68...reading file /dnc2020/2020-01-31 19:43:17.709738--2/output_2.txt.gz
# ..........processed 0 tweets
# 60/68...reading file /dnc2020/2020-01-31 19:44:42.861891--3/output_3.txt.gz
# ..........processed 0 tweets
# 61/68...reading file /dnc2020/2020-01-31 19:44:27.803077--2/output_2.txt.gz
# ..........processed 0 tweets
# 62/68...reading file /dnc2020/2020-01-31 19:45:40.131220--2/output_2.txt.gz
# ..........processed 44931 tweets
# 63/68...reading file /dnc2020/2020-01-31 19:45:30.122171--4/output_4.txt.gz
# ..........processed 0 tweets
# 64/68...reading file /dnc2020/2020-01-31 19:43:17.736067--5/output_5.txt.gz
# ..........processed 0 tweets
# 65/68...reading file /dnc2020/2020-01-31 19:45:20.098147--2/output_2.txt.gz
# ..........processed 0 tweets
# 66/68...reading file /dnc2020/2020-01-31 19:45:40.141759--5/output_5.txt.gz
# ..........processed 52699 tweets
# 67/68...reading file /dnc2020/2020-01-31 19:45:30.105274--3/output_3.txt.gz
# ..........processed 0 tweets
# 68/68...reading file /dnc2020/2020-01-31 19:42:37.660502--5/output_5.txt.gz
# ..........processed 0 tweets
#
# Number of tweets on 2020-01-31: 968409
#
# 1/7...reading file /dnc2020/2020-03-19 16:10:16.537948--4/output_4.txt.gz
# ..........processed 1811063 tweets
# 2/7...reading file /dnc2020/2020-03-19 16:04:46.796296--3/output_3.txt.gz
# ..........processed 1077506 tweets
# 3/7...reading file /dnc2020/2020-03-19 16:15:48.922674--2/output_2.txt.gz
# ..........processed 950106 tweets
# 4/7...reading file /dnc2020/2020-03-19 15:37:12.175841--5/output_5.txt.gz
# ..........processed 2228914 tweets
# 5/7...reading file /dnc2020/2020-03-19 15:48:13.567858--4/output_4.txt.gz
# ..........processed 4790 tweets
# 6/7...reading file /dnc2020/2020-03-19 15:59:16.077983--4/output_4.txt.gz
# ..........processed 4651 tweets
# 7/7...reading file /dnc2020/2020-03-19 16:15:46.137298--1/output_1.txt.gz
# ..........processed 813668 tweets
#
# Number of tweets on 2020-03-19: 6890698
#
# 1/4...reading file /dnc2020/2020-02-19 01:06:30.703882--2/output_2.txt.gz
# ..........processed 362394 tweets
# 2/4...reading file /dnc2020/2020-02-19 00:51:25.103151--4/output_4.txt.gz
# ..........processed 2532522 tweets
# 3/4...reading file /dnc2020/2020-02-19 00:43:27.135858--1/output_1.txt.gz
# ..........processed 178627 tweets
# 4/4...reading file /dnc2020/2020-02-19 00:47:50.822843--3/output_3.txt.gz
# ..........processed 1107206 tweets
#
# Number of tweets on 2020-02-19: 4180749
#
# 1/2...reading file /dnc2020/2020-02-17 15:32:11.711797--5/output_5.txt.gz
# ..........processed 286825 tweets
# 2/2...reading file /dnc2020/2020-02-17 16:04:55.544368--4/output_4.txt.gz
# ..........processed 1269078 tweets
#
# Number of tweets on 2020-02-17: 1555903
#
# 1/8...reading file /dnc2020/2020-02-26 13:44:52.037572--1/output_1.txt.gz
# EOFError..processed 55700 tweets
# 2/8...reading file /dnc2020/2020-02-26 00:11:42.191925--2/output_2.txt.gz
# ..........processed 167248 tweets
# 3/8...reading file /dnc2020/2020-02-26 22:48:15.027858--5/output_5.txt.gz
# EOFError..processed 77600 tweets
# 4/8...reading file /dnc2020/2020-02-26 13:41:08.904416--5/output_5.txt.gz
# ..........processed 1766 tweets
# 5/8...reading file /dnc2020/2020-02-26 13:46:32.103849--5/output_5.txt.gz
# ..........processed 306199 tweets
# 6/8...reading file /dnc2020/2020-02-26 13:39:29.632984--3/output_3.txt.gz
# EOFError..processed 442000 tweets
# 7/8...reading file /dnc2020/2020-02-26 13:47:44.950671--2/output_2.txt.gz
# EOFError..processed 120400 tweets
# 8/8...reading file /dnc2020/2020-02-26 13:40:52.866360--4/output_4.txt.gz
# EOFError..processed 835100 tweets
#
# Number of tweets on 2020-02-26: 2006234
#
# 1/13...reading file /dnc2020/2020-03-17 14:09:56.226597--3/output_3.txt.gz
# ..........processed 40754 tweets
# 2/13...reading file /dnc2020/2020-03-17 17:16:11.553967--2/output_2.txt.gz
# ..........processed 22410 tweets
# 3/13...reading file /dnc2020/2020-03-17 19:25:12.821690--4/output_4.txt.gz
# ..........processed 1490209 tweets
# 4/13...reading file /dnc2020/2020-03-17 14:07:07.272925--2/output_2.txt.gz
# ..........processed 13700 tweets
# 5/13...reading file /dnc2020/2020-03-17 15:58:58.234020--3/output_3.txt.gz
# ..........processed 42355 tweets
# 6/13...reading file /dnc2020/2020-03-17 18:18:53.492433--3/output_3.txt.gz
# ..........processed 1240294 tweets
# 7/13...reading file /dnc2020/2020-03-17 19:25:34.233982--2/output_2.txt.gz
# ..........processed 232745 tweets
# 8/13...reading file /dnc2020/2020-03-17 17:54:26.770053--3/output_3.txt.gz
# ..........processed 7427 tweets
# 9/13...reading file /dnc2020/2020-03-17 14:04:32.856499--5/output_5.txt.gz
# ..........processed 1855 tweets
# 10/13...reading file /dnc2020/2020-03-17 14:15:57.337987--5/output_5.txt.gz
# ..........processed 50476 tweets
# 11/13...reading file /dnc2020/2020-03-17 14:13:12.262000--4/output_4.txt.gz
# ..........processed 154711 tweets
# 12/13...reading file /dnc2020/2020-03-17 14:04:32.867608--1/output_1.txt.gz
# ..........processed 193471 tweets
# 13/13...reading file /dnc2020/2020-03-17 18:18:53.695922--5/output_5.txt.gz
# ..........processed 510679 tweets
#
# Number of tweets on 2020-03-17: 4001086
#
# 1/7...reading file /dnc2020/2020-03-13 21:26:58.516907--3/output_3.txt.gz
# ..........processed 3042634 tweets
# 2/7...reading file /dnc2020/2020-03-13 14:54:09.569994--3/output_3.txt.gz
# ..........processed 273548 tweets
# 3/7...reading file /dnc2020/2020-03-13 21:15:59.444024--5/output_5.txt.gz
# ..........processed 6640 tweets
# 4/7...reading file /dnc2020/2020-03-13 21:27:00.069998--2/output_2.txt.gz
# ..........processed 501742 tweets
# 5/7...reading file /dnc2020/2020-03-13 21:32:30.521528--1/output_1.txt.gz
# ..........processed 22725 tweets
# 6/7...reading file /dnc2020/2020-03-13 21:43:30.222013--4/output_4.txt.gz
# ..........processed 2107885 tweets
# 7/7...reading file /dnc2020/2020-03-13 21:32:29.566722--5/output_5.txt.gz
# ..........processed 294832 tweets
#
# Number of tweets on 2020-03-13: 6250006
#
# 1/1...reading file /dnc2020/2020-02-29 14:05:04.131860--2/output_2.txt.gz
# ..........processed 810582 tweets
#
# Number of tweets on 2020-02-29: 810582
#
# 1/26...reading file /dnc2020/2020-02-14 20:01:01.665054--5/output_5.txt.gz
# ..........processed 14620 tweets
# 2/26...reading file /dnc2020/2020-02-14 22:11:21.921222--5/output_5.txt.gz
# ..........processed 301993 tweets
# 3/26...reading file /dnc2020/2020-02-14 17:23:45.506946--4/output_4.txt.gz
# EOFError..processed 105400 tweets
# 4/26...reading file /dnc2020/2020-02-14 21:16:08.431857--1/output_1.txt.gz
# ..........processed 245276 tweets
# 5/26...reading file /dnc2020/2020-02-14 17:00:04.776042--2/output_2.txt.gz
# ..........processed 2380 tweets
# 6/26...reading file /dnc2020/2020-02-14 20:01:01.664116--4/output_4.txt.gz
# ..........processed 75813 tweets
# 7/26...reading file /dnc2020/2020-02-14 19:44:46.519859--5/output_5.txt.gz
# EOFError..processed 800 tweets
# 8/26...reading file /dnc2020/2020-02-14 22:03:38.703678--4/output_4.txt.gz
# ..........processed 1668842 tweets
# 9/26...reading file /dnc2020/2020-02-14 17:23:54.935538--5/output_5.txt.gz
# ..........processed 15091 tweets
# 10/26...reading file /dnc2020/2020-02-14 20:01:01.663112--3/output_3.txt.gz
# ..........processed 14420 tweets
# 11/26...reading file /dnc2020/2020-02-14 20:01:01.662260--2/output_2.txt.gz
# ..........processed 518575 tweets
# 12/26...reading file /dnc2020/2020-02-14 22:26:32.991858--3/output_3.txt.gz
# ..........processed 1751623 tweets
# 13/26...reading file /dnc2020/2020-02-14 17:13:35.953057--4/output_4.txt.gz
# ..........processed 4874 tweets
# 14/26...reading file /dnc2020/2020-02-14 21:01:23.530752--3/output_3.txt.gz
# ..........processed 21601 tweets
# 15/26...reading file /dnc2020/2020-02-14 17:09:10.887856--3/output_3.txt.gz
# ..........processed 2772 tweets
# 16/26...reading file /dnc2020/2020-02-14 17:21:06.127857--3/output_3.txt.gz
# EOFError..processed 42400 tweets
# 17/26...reading file /dnc2020/2020-02-14 20:01:01.661765--1/output_1.txt.gz
# ..........processed 3186 tweets
# 18/26...reading file /dnc2020/2020-02-14 17:09:04.467855--4/output_4.txt.gz
# ..........processed 875 tweets
# 19/26...reading file /dnc2020/2020-02-14 08:45:29.515859--1/output_1.txt.gz
# ..........processed 9077 tweets
# 20/26...reading file /dnc2020/2020-02-14 17:01:27.355861--1/output_1.txt.gz
# ..........processed 489 tweets
# 21/26...reading file /dnc2020/2020-02-14 04:11:10.299855--1/output_1.txt.gz
# ..........processed 5491 tweets
# 22/26...reading file /dnc2020/2020-02-14 08:45:29.663854--5/output_5.txt.gz
# ..........processed 40604 tweets
# 23/26...reading file /dnc2020/2020-02-14 17:25:20.070017--1/output_1.txt.gz
# EOFError..processed 6000 tweets
# 24/26...reading file /dnc2020/2020-02-14 04:11:07.760205--5/output_5.txt.gz
# ..........processed 13425 tweets
# 25/26...reading file /dnc2020/2020-02-14 17:10:14.755859--5/output_5.txt.gz
# ..........processed 1372 tweets
# 26/26...reading file /dnc2020/2020-02-14 17:23:54.935614--2/output_2.txt.gz
# EOFError..processed 18400 tweets
#
# Number of tweets on 2020-02-14: 4885678
#
# 1/2...reading file /dnc2020/2020-02-09 15:04:01.290728--1/output_1.txt.gz
# ..........processed 0 tweets
# 2/2...reading file /dnc2020/2020-02-09 15:05:43.972635--2/output_2.txt.gz
# ..........processed 107886 tweets
#
# Number of tweets on 2020-02-09: 107886
#
# 1/13...reading file /dnc2020/2020-02-21 00:57:26.982560--5/output_5.txt.gz
# ..........processed 209448 tweets
# 2/13...reading file /dnc2020/2020-02-21 16:05:06.230111--2/output_2.txt.gz
# ..........processed 59976 tweets
# 3/13...reading file /dnc2020/2020-02-21 22:16:53.947840--5/output_5.txt.gz
# ..........processed 7626 tweets
# 4/13...reading file /dnc2020/2020-02-21 23:12:04.299663--3/output_3.txt.gz
# ..........processed 1470998 tweets
# 5/13...reading file /dnc2020/2020-02-21 00:57:43.211818--4/output_4.txt.gz
# ..........processed 867794 tweets
# 6/13...reading file /dnc2020/2020-02-21 22:00:26.119849--1/output_1.txt.gz
# ..........processed 4102 tweets
# 7/13...reading file /dnc2020/2020-02-21 22:16:54.683848--4/output_4.txt.gz
# ..........processed 90556 tweets
# 8/13...reading file /dnc2020/2020-02-21 22:50:05.593962--1/output_1.txt.gz
# ..........processed 1318 tweets
# 9/13...reading file /dnc2020/2020-02-21 22:05:54.667890--2/output_2.txt.gz
# ..........processed 10079 tweets
# 10/13...reading file /dnc2020/2020-02-21 23:12:03.634668--5/output_5.txt.gz
# ..........processed 693938 tweets
# 11/13...reading file /dnc2020/2020-02-21 23:11:56.603854--4/output_4.txt.gz
# ..........processed 6754933 tweets
# 12/13...reading file /dnc2020/2020-02-21 23:17:32.055867--2/output_2.txt.gz
# ..........processed 783360 tweets
# 13/13...reading file /dnc2020/2020-02-21 23:06:37.143856--1/output_1.txt.gz
# ..........processed 355968 tweets
#
# Number of tweets on 2020-02-21: 11310096
#
# 1/7...reading file /dnc2020/2020-03-27 04:36:46.294122--5/output_5.txt.gz
# ..........processed 2737 tweets
# 2/7...reading file /dnc2020/2020-03-27 04:57:58.713578--1/output_1.txt.gz
# EOFError..processed 139600 tweets
# 3/7...reading file /dnc2020/2020-03-27 05:14:20.518000--5/output_5.txt.gz
# ..........processed 234760 tweets
# 4/7...reading file /dnc2020/2020-03-27 04:44:42.517985--1/output_1.txt.gz
# ..........processed 792 tweets
# 5/7...reading file /dnc2020/2020-03-27 02:51:45.561985--5/output_5.txt.gz
# ..........processed 10826 tweets
# 6/7...reading file /dnc2020/2020-03-27 05:31:06.229988--2/output_2.txt.gz
# ..........processed 25943 tweets
# 7/7...reading file /dnc2020/2020-03-27 15:07:04.208165--2/output_2.txt.gz
# EOFError..processed 93600 tweets
#
# Number of tweets on 2020-03-27: 508363
#
# 1/7...reading file /dnc2020/2020-02-05 17:39:15.810019--2/output_2.txt.gz
# ..........processed 598107 tweets
# 2/7...reading file /dnc2020/2020-02-05 17:16:56.267018--3/output_3.txt.gz
# ..........processed 2898994 tweets
# 3/7...reading file /dnc2020/2020-02-05 16:32:37.722750--5/output_5.txt.gz
# ..........processed 1374941 tweets
# 4/7...reading file /dnc2020/2020-02-05 18:14:34.065641--1/output_1.txt.gz
# ..........processed 328848 tweets
# 5/7...reading file /dnc2020/2020-02-05 16:47:47.606799--4/output_4.txt.gz
# ..........processed 2452313 tweets
# 6/7...reading file /dnc2020/2020-02-05 04:57:07.525197--5/output_5.txt.gz
# ..........processed 90401 tweets
# 7/7...reading file /dnc2020/2020-02-05 04:57:07.381564--4/output_4.txt.gz
# ..........processed 210028 tweets
#
# Number of tweets on 2020-02-05: 7953632
#
# 1/5...reading file /dnc2020/2020-02-08 16:26:44.123647--5/output_5.txt.gz
# ..........processed 684919 tweets
# 2/5...reading file /dnc2020/2020-02-08 16:14:22.105009--5/output_5.txt.gz
# ..........processed 7243 tweets
# 3/5...reading file /dnc2020/2020-02-08 10:29:32.823253--4/output_4.txt.gz
# ..........processed 184535 tweets
# 4/5...reading file /dnc2020/2020-02-08 11:47:09.289813--5/output_5.txt.gz
# ..........processed 146092 tweets
# 5/5...reading file /dnc2020/2020-02-08 16:14:21.874678--4/output_4.txt.gz
# ..........processed 1402650 tweets
#
# Number of tweets on 2020-02-08: 2425439
#
# 1/9...reading file /dnc2020/2020-03-04 18:53:26.721022--4/output_4.txt.gz
# EOFError..processed 2094600 tweets
# 2/9...reading file /dnc2020/2020-03-04 18:23:21.055859--4/output_4.txt.gz
# ..........processed 46547 tweets
# 3/9...reading file /dnc2020/2020-03-04 19:09:27.355807--1/output_1.txt.gz
# ..........processed 6882 tweets
# 4/9...reading file /dnc2020/2020-03-04 17:45:02.627854--3/output_3.txt.gz
# ..........processed 300130 tweets
# 5/9...reading file /dnc2020/2020-03-04 20:24:17.263861--3/output_3.txt.gz
# EOFError..processed 1835500 tweets
# 6/9...reading file /dnc2020/2020-03-04 02:37:08.024408--2/output_2.txt.gz
# ..........processed 179948 tweets
# 7/9...reading file /dnc2020/2020-03-04 20:47:35.601357--2/output_2.txt.gz
# EOFError..processed 327200 tweets
# 8/9...reading file /dnc2020/2020-03-04 20:23:41.707865--1/output_1.txt.gz
# EOFError..processed 96500 tweets
# 9/9...reading file /dnc2020/2020-03-04 17:29:29.331859--2/output_2.txt.gz
# ..........processed 55678 tweets
#
# Number of tweets on 2020-03-04: 4943136
#
# 1/6...reading file /dnc2020/2020-01-27 18:46:57.166225--1/output_1.txt.gz
# ..........processed 122107 tweets
# 2/6...reading file /dnc2020/2020-01-27 17:17:29.136855--5/output_5.txt.gz
# ..........processed 577962 tweets
# 3/6...reading file /dnc2020/2020-01-27 17:17:29.131172--4/output_4.txt.gz
# ..........processed 1581192 tweets
# 4/6...reading file /dnc2020/2020-01-27 17:17:29.128329--1/output_1.txt.gz
# ..........processed 2264 tweets
# 5/6...reading file /dnc2020/2020-01-27 17:17:29.128835--2/output_2.txt.gz
# ..........processed 301676 tweets
# 6/6...reading file /dnc2020/2020-01-27 17:17:29.129724--3/output_3.txt.gz
# ..........processed 1479432 tweets
#
# Number of tweets on 2020-01-27: 4064633
#
# 1/12...reading file /dnc2020/2020-02-20 15:19:51.317214--2/output_2.txt.gz
# ..........processed 85946 tweets
# 2/12...reading file /dnc2020/2020-02-20 22:22:44.855864--3/output_3.txt.gz
# ..........processed 24236 tweets
# 3/12...reading file /dnc2020/2020-02-20 23:38:03.847858--1/output_1.txt.gz
# ..........processed 69173 tweets
# 4/12...reading file /dnc2020/2020-02-20 21:27:34.979841--1/output_1.txt.gz
# ..........processed 5594 tweets
# 5/12...reading file /dnc2020/2020-02-20 20:40:04.143859--3/output_3.txt.gz
# ..........processed 27432 tweets
# 6/12...reading file /dnc2020/2020-02-20 22:05:18.189114--4/output_4.txt.gz
# ..........processed 192858 tweets
# 7/12...reading file /dnc2020/2020-02-20 23:07:24.963856--2/output_2.txt.gz
# ..........processed 154847 tweets
# 8/12...reading file /dnc2020/2020-02-20 20:16:30.232504--4/output_4.txt.gz
# ..........processed 131311 tweets
# 9/12...reading file /dnc2020/2020-02-20 22:05:31.911860--3/output_3.txt.gz
# ..........processed 5049 tweets
# 10/12...reading file /dnc2020/2020-02-20 21:35:51.366838--5/output_5.txt.gz
# ..........processed 76716 tweets
# 11/12...reading file /dnc2020/2020-02-20 22:45:51.612558--1/output_1.txt.gz
# ..........processed 4360 tweets
# 12/12...reading file /dnc2020/2020-02-20 23:31:57.975823--3/output_3.txt.gz
# ..........processed 340094 tweets
#
# Number of tweets on 2020-02-20: 1117616
#
# 1/10...reading file /dnc2020/2020-02-25 21:20:21.495179--5/output_5.txt.gz
# ..........processed 10270 tweets
# 2/10...reading file /dnc2020/2020-02-25 23:48:55.948057--3/output_3.txt.gz
# ..........processed 567981 tweets
# 3/10...reading file /dnc2020/2020-02-25 22:39:52.751854--5/output_5.txt.gz
# ..........processed 986083 tweets
# 4/10...reading file /dnc2020/2020-02-25 22:47:16.430595--4/output_4.txt.gz
# ..........processed 1090938 tweets
# 5/10...reading file /dnc2020/2020-02-25 20:49:16.719859--5/output_5.txt.gz
# ..........processed 8590 tweets
# 6/10...reading file /dnc2020/2020-02-25 21:58:14.123859--5/output_5.txt.gz
# ..........processed 10852 tweets
# 7/10...reading file /dnc2020/2020-02-25 20:33:24.223982--3/output_3.txt.gz
# ..........processed 41104 tweets
# 8/10...reading file /dnc2020/2020-02-25 22:24:08.727860--3/output_3.txt.gz
# ..........processed 33240 tweets
# 9/10...reading file /dnc2020/2020-02-25 23:17:55.471857--2/output_2.txt.gz
# ..........processed 8331 tweets
# 10/10...reading file /dnc2020/2020-02-25 22:39:57.415861--1/output_1.txt.gz
# ..........processed 72658 tweets
#
# Number of tweets on 2020-02-25: 2830047
#
# 1/11...reading file /dnc2020/2020-03-10 05:34:49.789995--1/output_1.txt.gz
# ..........processed 35384 tweets
# 2/11...reading file /dnc2020/2020-03-10 21:48:09.721953--4/output_4.txt.gz
# EOFError..processed 979100 tweets
# 3/11...reading file /dnc2020/2020-03-10 21:10:39.325970--1/output_1.txt.gz
# EOFError..processed 70400 tweets
# 4/11...reading file /dnc2020/2020-03-10 21:10:15.543478--3/output_3.txt.gz
# EOFError..processed 1642000 tweets
# 5/11...reading file /dnc2020/2020-03-10 21:02:34.403938--4/output_4.txt.gz
# ..........processed 44841 tweets
# 6/11...reading file /dnc2020/2020-03-10 05:34:42.877960--4/output_4.txt.gz
# ..........processed 647137 tweets
# 7/11...reading file /dnc2020/2020-03-10 21:41:55.597989--2/output_2.txt.gz
# EOFError..processed 87100 tweets
# 8/11...reading file /dnc2020/2020-03-10 19:38:09.589955--5/output_5.txt.gz
# ..........processed 22449 tweets
# 9/11...reading file /dnc2020/2020-03-10 21:10:24.061973--5/output_5.txt.gz
# EOFError..processed 186600 tweets
# 10/11...reading file /dnc2020/2020-03-10 18:03:26.945108--1/output_1.txt.gz
# ..........processed 14733 tweets
# 11/11...reading file /dnc2020/2020-03-10 05:34:42.877994--2/output_2.txt.gz
# ..........processed 121264 tweets
#
# Number of tweets on 2020-03-10: 3851268
#
# 1/2...reading file /dnc2020/2020-03-08 15:20:46.015836--3/output_3.txt.gz
# EOFError..processed 1587500 tweets
# 2/2...reading file /dnc2020/2020-03-08 15:31:58.597643--2/output_2.txt.gz
# EOFError..processed 219800 tweets
#
# Number of tweets on 2020-03-08: 1807364
#
# 1/11...reading file /dnc2020/2020-02-10 15:03:11.005932--5/output_5.txt.gz
# ..........processed 62815 tweets
# 2/11...reading file /dnc2020/2020-02-10 23:16:55.975060--4/output_4.txt.gz
# EOFError..processed 430500 tweets
# 3/11...reading file /dnc2020/2020-02-10 21:57:21.681362--3/output_3.txt.gz
# ..........processed 28700 tweets
# 4/11...reading file /dnc2020/2020-02-10 15:19:31.978044--2/output_2.txt.gz
# ..........processed 42253 tweets
# 5/11...reading file /dnc2020/2020-02-10 21:27:48.453912--5/output_5.txt.gz
# ..........processed 42400 tweets
# 6/11...reading file /dnc2020/2020-02-10 23:00:28.045788--3/output_3.txt.gz
# EOFError..processed 300100 tweets
# 7/11...reading file /dnc2020/2020-02-10 18:42:55.379264--5/output_5.txt.gz
# ..........processed 28576 tweets
# 8/11...reading file /dnc2020/2020-02-10 15:05:11.558514--4/output_4.txt.gz
# ..........processed 318657 tweets
# 9/11...reading file /dnc2020/2020-02-10 19:50:29.292059--3/output_3.txt.gz
# ..........processed 59310 tweets
# 10/11...reading file /dnc2020/2020-02-10 23:11:33.096325--2/output_2.txt.gz
# ..........processed 25684 tweets
# 11/11...reading file /dnc2020/2020-02-10 20:49:13.207272--5/output_5.txt.gz
# ..........processed 7497 tweets
#
# Number of tweets on 2020-02-10: 1346655
#
# 1/11...reading file /dnc2020/2020-02-12 20:54:37.149507--2/output_2.txt.gz
# ..........processed 115571 tweets
# 2/11...reading file /dnc2020/2020-02-12 20:27:38.595867--2/output_2.txt.gz
# ..........processed 3654 tweets
# 3/11...reading file /dnc2020/2020-02-12 18:47:01.715858--3/output_3.txt.gz
# ..........processed 25556 tweets
# 4/11...reading file /dnc2020/2020-02-12 20:12:20.375863--5/output_5.txt.gz
# ..........processed 3839 tweets
# 5/11...reading file /dnc2020/2020-02-12 20:41:35.102698--5/output_5.txt.gz
# ..........processed 212630 tweets
# 6/11...reading file /dnc2020/2020-02-12 21:30:48.545614--3/output_3.txt.gz
# ..........processed 578187 tweets
# 7/11...reading file /dnc2020/2020-02-12 19:25:40.263396--3/output_3.txt.gz
# ..........processed 81057 tweets
# 8/11...reading file /dnc2020/2020-02-12 15:17:00.495839--5/output_5.txt.gz
# ..........processed 45001 tweets
# 9/11...reading file /dnc2020/2020-02-12 20:38:48.737752--1/output_1.txt.gz
# ..........processed 1724 tweets
# 10/11...reading file /dnc2020/2020-02-12 21:02:41.055864--1/output_1.txt.gz
# ..........processed 100388 tweets
# 11/11...reading file /dnc2020/2020-02-12 22:13:35.442689--4/output_4.txt.gz
# ..........processed 1371206 tweets
#
# Number of tweets on 2020-02-12: 2538813
#
# 1/8...reading file /dnc2020/2020-02-11 14:42:58.529905--5/output_5.txt.gz
# ..........processed 138027 tweets
# 2/8...reading file /dnc2020/2020-02-11 00:38:04.509066--5/output_5.txt.gz
# EOFError..processed 110800 tweets
# 3/8...reading file /dnc2020/2020-02-11 22:42:22.483871--5/output_5.txt.gz
# ..........processed 137840 tweets
# 4/8...reading file /dnc2020/2020-02-11 02:59:58.866280--2/output_2.txt.gz
# EOFError..processed 28100 tweets
# 5/8...reading file /dnc2020/2020-02-11 14:42:58.524449--3/output_3.txt.gz
# ..........processed 1228989 tweets
# 6/8...reading file /dnc2020/2020-02-11 14:42:58.525001--4/output_4.txt.gz
# ..........processed 1993036 tweets
# 7/8...reading file /dnc2020/2020-02-11 14:42:58.523337--1/output_1.txt.gz
# ..........processed 107685 tweets
# 8/8...reading file /dnc2020/2020-02-11 14:42:58.523990--2/output_2.txt.gz
# ..........processed 288831 tweets
#
# Number of tweets on 2020-02-11: 4033384
#
# 1/11...reading file /dnc2020/2020-03-05 20:57:23.081390--3/output_3.txt.gz
# ..........processed 794171 tweets
# 2/11...reading file /dnc2020/2020-03-05 20:55:54.167030--2/output_2.txt.gz
# EOFError..processed 100 tweets
# 3/11...reading file /dnc2020/2020-03-05 20:55:54.166579--1/output_1.txt.gz
# ..........processed 0 tweets
# 4/11...reading file /dnc2020/2020-03-05 14:10:49.047858--5/output_5.txt.gz
# EOFError..processed 156000 tweets
# 5/11...reading file /dnc2020/2020-03-05 20:57:23.080822--2/output_2.txt.gz
# ..........processed 167814 tweets
# 6/11...reading file /dnc2020/2020-03-05 20:55:54.167466--3/output_3.txt.gz
# EOFError..processed 2200 tweets
# 7/11...reading file /dnc2020/2020-03-05 20:55:54.169287--5/output_5.txt.gz
# EOFError..processed 400 tweets
# 8/11...reading file /dnc2020/2020-03-05 20:57:23.082128--4/output_4.txt.gz
# ..........processed 927164 tweets
# 9/11...reading file /dnc2020/2020-03-05 20:55:54.168004--4/output_4.txt.gz
# EOFError..processed 2500 tweets
# 10/11...reading file /dnc2020/2020-03-05 20:57:23.082540--5/output_5.txt.gz
# ..........processed 194829 tweets
# 11/11...reading file /dnc2020/2020-03-05 20:57:23.080300--1/output_1.txt.gz
# ..........processed 116792 tweets
#
# Number of tweets on 2020-03-05: 2362238
#
# 1/2...reading file /dnc2020/2020-02-13 19:35:11.700429--3/output_3.txt.gz
# ..........processed 376954 tweets
# 2/2...reading file /dnc2020/2020-02-13 19:35:11.700096--2/output_2.txt.gz
# ..........processed 103905 tweets
#
# Number of tweets on 2020-02-13: 480859
#
# 1/1...reading file /dnc2020/2020-03-25 14:48:16.700625--1/output_1.txt.gz
# ..........processed 104267 tweets
#
# Number of tweets on 2020-03-25: 104267
#
# 1/8...reading file /dnc2020/2020-02-27 14:25:24.707856--2/output_2.txt.gz
# ..........processed 294485 tweets
# 2/8...reading file /dnc2020/2020-02-27 02:39:44.595406--3/output_3.txt.gz
# ..........processed 232768 tweets
# 3/8...reading file /dnc2020/2020-02-27 02:39:44.595031--2/output_2.txt.gz
# ..........processed 103078 tweets
# 4/8...reading file /dnc2020/2020-02-27 16:41:43.201210--3/output_3.txt.gz
# ..........processed 5665889 tweets
# 5/8...reading file /dnc2020/2020-02-27 02:39:44.595854--4/output_4.txt.gz
# ..........processed 7880798 tweets
# 6/8...reading file /dnc2020/2020-02-27 02:39:44.594563--1/output_1.txt.gz
# ..........processed 456930 tweets
# 7/8...reading file /dnc2020/2020-02-27 15:41:00.711858--3/output_3.txt.gz
# ..........processed 18223 tweets
# 8/8...reading file /dnc2020/2020-02-27 02:39:44.597110--5/output_5.txt.gz
# ..........processed 2820421 tweets
#
# Number of tweets on 2020-02-27: 17472592
#
# 1/5...reading file /dnc2020/2020-03-06 09:10:57.537970--2/output_2.txt.gz
# ..........processed 522035 tweets
# 2/5...reading file /dnc2020/2020-03-06 18:31:40.260643--1/output_1.txt.gz
# EOFError..processed 281100 tweets
# 3/5...reading file /dnc2020/2020-03-06 06:27:00.095851--5/output_5.txt.gz
# EOFError..processed 845300 tweets
# 4/5...reading file /dnc2020/2020-03-06 06:26:59.965461--3/output_3.txt.gz
# ..........processed 3078193 tweets
# 5/5...reading file /dnc2020/2020-03-06 06:26:58.127865--4/output_4.txt.gz
# EOFError..processed 4176300 tweets
#
# Number of tweets on 2020-03-06: 8903063
#
# 1/9...reading file /dnc2020/2020-01-30 03:51:26.726817--5/output_5.txt.gz
# ..........processed 3031 tweets
# 2/9...reading file /dnc2020/2020-01-30 02:33:40.926286--1/output_1.txt.gz
# ..........processed 53854 tweets
# 3/9...reading file /dnc2020/2020-01-30 03:58:41.038650--3/output_3.txt.gz
# ..........processed 567810 tweets
# 4/9...reading file /dnc2020/2020-01-30 05:08:00.154786--2/output_2.txt.gz
# ..........processed 88878 tweets
# 5/9...reading file /dnc2020/2020-01-30 04:09:09.053616--4/output_4.txt.gz
# ..........processed 661036 tweets
# 6/9...reading file /dnc2020/2020-01-30 04:12:56.019411--5/output_5.txt.gz
# ..........processed 209401 tweets
# 7/9...reading file /dnc2020/2020-01-30 04:51:53.762948--2/output_2.txt.gz
# ..........processed 1800 tweets
# 8/9...reading file /dnc2020/2020-01-30 03:13:06.736436--5/output_5.txt.gz
# ..........processed 1991 tweets
# 9/9...reading file /dnc2020/2020-01-30 03:27:56.142979--5/output_5.txt.gz
# ..........processed 3313 tweets
#
# Number of tweets on 2020-01-30: 1591114
#
# 1/7...reading file /dnc2020/2020-03-03 22:39:19.403856--3/output_3.txt.gz
# ..........processed 2004170 tweets
# 2/7...reading file /dnc2020/2020-03-03 22:19:13.441303--3/output_3.txt.gz
# ..........processed 18423 tweets
# 3/7...reading file /dnc2020/2020-03-03 22:19:20.843814--2/output_2.txt.gz
# ..........processed 76691 tweets
# 4/7...reading file /dnc2020/2020-03-03 22:39:48.090797--1/output_1.txt.gz
# ..........processed 141308 tweets
# 5/7...reading file /dnc2020/2020-03-03 22:24:40.805206--5/output_5.txt.gz
# ..........processed 1157793 tweets
# 6/7...reading file /dnc2020/2020-03-03 22:22:55.403859--4/output_4.txt.gz
# ..........processed 1968200 tweets
# 7/7...reading file /dnc2020/2020-03-03 22:17:40.943855--1/output_1.txt.gz
# ..........processed 3368 tweets
#
# Number of tweets on 2020-03-03: 5369953
#
# 1/2...reading file /dnc2020/2020-03-12 06:28:21.727201--2/output_2.txt.gz
# ..........processed 402980 tweets
# 2/2...reading file /dnc2020/2020-03-12 05:42:57.833163--2/output_2.txt.gz
# ..........processed 2791 tweets
#
# Number of tweets on 2020-03-12: 405771
#
# 1/3...reading file /dnc2020/2020-02-18 23:57:48.805373--5/output_5.txt.gz
# ..........processed 1498924 tweets
# 2/3...reading file /dnc2020/2020-02-18 21:52:08.141068--1/output_1.txt.gz
# ..........processed 11389 tweets
# 3/3...reading file /dnc2020/2020-02-18 21:36:07.675876--1/output_1.txt.gz
# ..........processed 625 tweets
#
# Number of tweets on 2020-02-18: 1510938
#
# 1/5...reading file /dnc2020/2020-03-09 17:46:31.439728--3/output_3.txt.gz
# ..........processed 1907844 tweets
# 2/5...reading file /dnc2020/2020-03-09 17:46:31.438855--1/output_1.txt.gz
# ..........processed 46462 tweets
# 3/5...reading file /dnc2020/2020-03-09 17:46:31.439315--2/output_2.txt.gz
# ..........processed 159509 tweets
# 4/5...reading file /dnc2020/2020-03-09 17:46:31.440144--5/output_5.txt.gz
# ..........processed 482058 tweets
# 5/5...reading file /dnc2020/2020-03-09 17:46:31.439948--4/output_4.txt.gz
# ..........processed 633790 tweets
#
# Number of tweets on 2020-03-09: 3229663
#
# 1/7...reading file /dnc2020/2020-03-11 14:39:22.693398--5/output_5.txt.gz
# ..........processed 1188119 tweets
# 2/7...reading file /dnc2020/2020-03-11 14:39:22.692923--4/output_4.txt.gz
# ..........processed 1782859 tweets
# 3/7...reading file /dnc2020/2020-03-11 20:24:06.185151--3/output_3.txt.gz
# ..........processed 1871055 tweets
# 4/7...reading file /dnc2020/2020-03-11 14:39:22.691604--1/output_1.txt.gz
# ..........processed 28388 tweets
# 5/7...reading file /dnc2020/2020-03-11 20:20:48.342002--1/output_1.txt.gz
# ..........processed 197841 tweets
# 6/7...reading file /dnc2020/2020-03-11 14:39:22.692481--3/output_3.txt.gz
# ..........processed 538922 tweets
# 7/7...reading file /dnc2020/2020-03-11 14:39:22.692056--2/output_2.txt.gz
# ..........processed 121213 tweets
#
# Number of tweets on 2020-03-11: 5728397
#
# 1/2...reading file /dnc2020/2020-03-24 07:44:03.377084--4/output_4.txt.gz
# ..........processed 771512 tweets
# 2/2...reading file /dnc2020/2020-03-24 07:25:22.039963--4/output_4.txt.gz
# ..........processed 1016 tweets
#
# Number of tweets on 2020-03-24: 772528
#
# 1/2...reading file /dnc2020/2020-03-14 14:10:47.701963--1/output_1.txt.gz
# ..........processed 43594 tweets
# 2/2...reading file /dnc2020/2020-03-14 16:25:42.726186--5/output_5.txt.gz
# ..........processed 1909082 tweets
#
# Number of tweets on 2020-03-14: 1952676
#
# 1/1...reading file /dnc2020/2020-03-15 05:34:48.296115--1/output_1.txt.gz
# ..........processed 279088 tweets
#
# Number of tweets on 2020-03-15: 279088
#
# 1/1...reading file /dnc2020/2020-03-21 15:05:38.330009--3/output_3.txt.gz
# ..........processed 3171933 tweets
#
# Number of tweets on 2020-03-21: 3171933
